# %%
from chat_agent.mongodb_agent import db_agent

# %%
user_query_1 = "Give me the values for deviceId SAG_DPv3_QA3 with code T and its creation dates"
agent_result_1 = db_agent(user_query_1)

# %%
user_query_2 = "provide me the values for deviceId SAG_DPv3_QA3 with code IT and its creation date"
agent_result_2 = db_agent(user_query_2)
